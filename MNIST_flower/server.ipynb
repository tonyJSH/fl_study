# %% [markdown]
# # Flower Server 코드
# - server 실행 시 strategy를 통해 다양한 설정값을 지정
# - output으로 각 라운드의 집계된 손실값과 성능 지표가 저장됨
#     - 성능 지표(아래 셀 에선 accuracy)는 evaluate_metrics_aggregation_fn을 통해 집계됨

# %% [markdown]
# ## 만약 아래 셀을 실행하고 연합학습 완료 전에 종료 시 '반드시 커널 재시작을 통해 초기화 해야 함'

# %% [markdown]
# # 1번

# %%
import flwr as fl
import os
import numpy as np

fraction_fit=1
fraction_eval=1
min_fit_clients=3
min_eval_clients=3
min_available_clients=3
num_rounds=30

def evaluate_metrics_aggregation_fn(eval_metrics):
    data_len = sum([num for num, met in eval_metrics])
    acc = sum([num*met['accuracy'] for num, met in eval_metrics])/data_len
    return {'accuracy' : acc}

strategy = fl.server.strategy.FedAvg(
    fraction_fit=fraction_fit,                    # 훈련을 위해서 사용 가능한 클라이언트의 100% 이용
    fraction_evaluate=fraction_eval,              # 평가를 위해서 사용 가능한 클라이언트의 100% 이용
    min_fit_clients=min_fit_clients,              # 훈련을 위해서는 적어도 5개 이상의 클라이언트가 필요
    min_evaluate_clients=min_eval_clients,        # 평가를 위해서는 적어도 5개 이상의 클라이언트가 필요
    min_available_clients=min_available_clients,  # 사용 가능한 클라이언트의 수가 5 될 때까지 대기
    evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
)

print('server start!')
output = fl.server.start_server(config=fl.server.ServerConfig(num_rounds=num_rounds), strategy=strategy)
output
# Out:
# 2023-08-23 17:13:51.380926: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-23 17:13:51.478588: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-23 17:13:51.502288: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-08-23 17:13:51.907341: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2023-08-23 17:13:51.907396: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2023-08-23 17:13:51.907401: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# INFO flwr 2023-08-23 17:13:52,302 | app.py:148 | Starting Flower server, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2023-08-23 17:13:52,310 | app.py:168 | Flower ECE: gRPC server running (30 rounds), SSL is disabled
# INFO flwr 2023-08-23 17:13:52,311 | server.py:86 | Initializing global parameters
# INFO flwr 2023-08-23 17:13:52,311 | server.py:273 | Requesting initial parameters from one random client
# server start!
# INFO flwr 2023-08-23 17:13:53,720 | server.py:277 | Received initial parameters from one random client
# INFO flwr 2023-08-23 17:13:53,722 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-08-23 17:13:53,723 | server.py:101 | FL starting
# DEBUG flwr 2023-08-23 17:13:58,350 | server.py:218 | fit_round 1: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:13:59,502 | server.py:232 | fit_round 1 received 3 results and 0 failures
# WARNING flwr 2023-08-23 17:13:59,506 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-08-23 17:13:59,507 | server.py:168 | evaluate_round 1: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:13:59,592 | server.py:182 | evaluate_round 1 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:13:59,593 | server.py:218 | fit_round 2: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:00,268 | server.py:232 | fit_round 2 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:00,273 | server.py:168 | evaluate_round 2: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:00,355 | server.py:182 | evaluate_round 2 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:00,356 | server.py:218 | fit_round 3: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:01,006 | server.py:232 | fit_round 3 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:01,009 | server.py:168 | evaluate_round 3: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:01,093 | server.py:182 | evaluate_round 3 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:01,094 | server.py:218 | fit_round 4: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:01,706 | server.py:232 | fit_round 4 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:01,711 | server.py:168 | evaluate_round 4: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:01,785 | server.py:182 | evaluate_round 4 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:01,787 | server.py:218 | fit_round 5: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:02,440 | server.py:232 | fit_round 5 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:02,444 | server.py:168 | evaluate_round 5: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:02,527 | server.py:182 | evaluate_round 5 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:02,527 | server.py:218 | fit_round 6: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:03,178 | server.py:232 | fit_round 6 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:03,183 | server.py:168 | evaluate_round 6: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:03,276 | server.py:182 | evaluate_round 6 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:03,277 | server.py:218 | fit_round 7: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:03,905 | server.py:232 | fit_round 7 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:03,910 | server.py:168 | evaluate_round 7: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:03,999 | server.py:182 | evaluate_round 7 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:04,000 | server.py:218 | fit_round 8: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:04,578 | server.py:232 | fit_round 8 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:04,581 | server.py:168 | evaluate_round 8: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:04,667 | server.py:182 | evaluate_round 8 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:04,669 | server.py:218 | fit_round 9: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:05,221 | server.py:232 | fit_round 9 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:05,226 | server.py:168 | evaluate_round 9: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:05,322 | server.py:182 | evaluate_round 9 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:05,323 | server.py:218 | fit_round 10: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:05,902 | server.py:232 | fit_round 10 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:05,906 | server.py:168 | evaluate_round 10: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:05,994 | server.py:182 | evaluate_round 10 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:05,995 | server.py:218 | fit_round 11: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:06,663 | server.py:232 | fit_round 11 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:06,667 | server.py:168 | evaluate_round 11: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:06,748 | server.py:182 | evaluate_round 11 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:06,749 | server.py:218 | fit_round 12: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:07,317 | server.py:232 | fit_round 12 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:07,322 | server.py:168 | evaluate_round 12: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:07,410 | server.py:182 | evaluate_round 12 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:07,412 | server.py:218 | fit_round 13: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:08,034 | server.py:232 | fit_round 13 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:08,038 | server.py:168 | evaluate_round 13: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:08,118 | server.py:182 | evaluate_round 13 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:08,119 | server.py:218 | fit_round 14: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:08,726 | server.py:232 | fit_round 14 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:08,730 | server.py:168 | evaluate_round 14: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:08,822 | server.py:182 | evaluate_round 14 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:08,823 | server.py:218 | fit_round 15: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:09,430 | server.py:232 | fit_round 15 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:09,434 | server.py:168 | evaluate_round 15: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:09,521 | server.py:182 | evaluate_round 15 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:09,522 | server.py:218 | fit_round 16: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:10,105 | server.py:232 | fit_round 16 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:10,110 | server.py:168 | evaluate_round 16: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:10,189 | server.py:182 | evaluate_round 16 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:10,191 | server.py:218 | fit_round 17: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:10,852 | server.py:232 | fit_round 17 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:10,856 | server.py:168 | evaluate_round 17: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:10,943 | server.py:182 | evaluate_round 17 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:10,944 | server.py:218 | fit_round 18: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:11,600 | server.py:232 | fit_round 18 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:11,604 | server.py:168 | evaluate_round 18: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:11,691 | server.py:182 | evaluate_round 18 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:11,692 | server.py:218 | fit_round 19: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:12,328 | server.py:232 | fit_round 19 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:12,331 | server.py:168 | evaluate_round 19: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:12,418 | server.py:182 | evaluate_round 19 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:12,419 | server.py:218 | fit_round 20: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:13,017 | server.py:232 | fit_round 20 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:13,021 | server.py:168 | evaluate_round 20: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:13,111 | server.py:182 | evaluate_round 20 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:13,112 | server.py:218 | fit_round 21: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:13,700 | server.py:232 | fit_round 21 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:13,704 | server.py:168 | evaluate_round 21: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:13,781 | server.py:182 | evaluate_round 21 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:13,782 | server.py:218 | fit_round 22: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:14,387 | server.py:232 | fit_round 22 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:14,390 | server.py:168 | evaluate_round 22: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:14,469 | server.py:182 | evaluate_round 22 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:14,470 | server.py:218 | fit_round 23: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:15,075 | server.py:232 | fit_round 23 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:15,078 | server.py:168 | evaluate_round 23: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:15,239 | server.py:182 | evaluate_round 23 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:15,240 | server.py:218 | fit_round 24: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:15,831 | server.py:232 | fit_round 24 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:15,835 | server.py:168 | evaluate_round 24: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:15,922 | server.py:182 | evaluate_round 24 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:15,923 | server.py:218 | fit_round 25: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:16,563 | server.py:232 | fit_round 25 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:16,568 | server.py:168 | evaluate_round 25: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:16,661 | server.py:182 | evaluate_round 25 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:16,662 | server.py:218 | fit_round 26: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:17,319 | server.py:232 | fit_round 26 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:17,322 | server.py:168 | evaluate_round 26: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:17,406 | server.py:182 | evaluate_round 26 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:17,407 | server.py:218 | fit_round 27: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:18,013 | server.py:232 | fit_round 27 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:18,016 | server.py:168 | evaluate_round 27: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:18,098 | server.py:182 | evaluate_round 27 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:18,099 | server.py:218 | fit_round 28: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:18,707 | server.py:232 | fit_round 28 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:18,712 | server.py:168 | evaluate_round 28: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:18,794 | server.py:182 | evaluate_round 28 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:18,795 | server.py:218 | fit_round 29: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:19,367 | server.py:232 | fit_round 29 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:19,372 | server.py:168 | evaluate_round 29: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:19,476 | server.py:182 | evaluate_round 29 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:19,477 | server.py:218 | fit_round 30: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:20,067 | server.py:232 | fit_round 30 received 3 results and 0 failures
# DEBUG flwr 2023-08-23 17:14:20,071 | server.py:168 | evaluate_round 30: strategy sampled 3 clients (out of 3)
# DEBUG flwr 2023-08-23 17:14:20,153 | server.py:182 | evaluate_round 30 received 3 results and 0 failures
# INFO flwr 2023-08-23 17:14:20,154 | server.py:147 | FL finished in 26.430115240975283
# INFO flwr 2023-08-23 17:14:20,154 | app.py:218 | app_fit: losses_distributed [(1, 2.025204820020737), (2, 1.746537595805544), (3, 1.6940215264495737), (4, 1.639001351131843), (5, 1.6116739337819301), (6, 1.609626164878324), (7, 1.6003387612040645), (8, 1.5936598701365483), (9, 1.5928263235611864), (10, 1.58816643226577), (11, 1.5826655055341596), (12, 1.5859700231096314), (13, 1.5830170263255694), (14, 1.585007597703765), (15, 1.5795950202414566), (16, 1.5758954636538796), (17, 1.5825104131399184), (18, 1.573346751902702), (19, 1.573436912352199), (20, 1.5727742527165587), (21, 1.5760614931458248), (22, 1.5713802739723053), (23, 1.5741849276509574), (24, 1.5723928663923958), (25, 1.5707435111572308), (26, 1.5717725491192374), (27, 1.567651174400058), (28, 1.5669317377673282), (29, 1.5640258584519813), (30, 1.568510140660834)]
# INFO flwr 2023-08-23 17:14:20,155 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-08-23 17:14:20,155 | app.py:220 | app_fit: metrics_distributed {'accuracy': [(1, 50.83491650834917), (2, 77.71222877712229), (3, 82.56174382561744), (4, 88.41115888411159), (5, 90.51094890510949), (6, 90.95090490950905), (7, 91.63083691630837), (8, 92.34076592340766), (9, 92.4007599240076), (10, 92.92070792920708), (11, 93.46065393460654), (12, 93.36066393360665), (13, 93.37066293370663), (14, 93.49065093490651), (15, 93.75062493750625), (16, 94.14058594140586), (17, 93.67063293670633), (18, 94.15058494150585), (19, 94.34056594340566), (20, 94.25057494250575), (21, 94.22057794220578), (22, 94.5905409459054), (23, 94.28057194280572), (24, 94.47055294470553), (25, 94.41055894410559), (26, 94.26057394260575), (27, 94.68053194680532), (28, 94.77052294770523), (29, 95.07049295070493), (30, 94.5905409459054)]}
# INFO flwr 2023-08-23 17:14:20,156 | app.py:221 | app_fit: losses_centralized []
# INFO flwr 2023-08-23 17:14:20,156 | app.py:222 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 2.025204820020737
# 	round 2: 1.746537595805544
# 	round 3: 1.6940215264495737
# 	round 4: 1.639001351131843
# 	round 5: 1.6116739337819301
# 	round 6: 1.609626164878324
# 	round 7: 1.6003387612040645
# 	round 8: 1.5936598701365483
# 	round 9: 1.5928263235611864
# 	round 10: 1.58816643226577
# 	round 11: 1.5826655055341596
# 	round 12: 1.5859700231096314
# 	round 13: 1.5830170263255694
# 	round 14: 1.585007597703765
# 	round 15: 1.5795950202414566
# 	round 16: 1.5758954636538796
# 	round 17: 1.5825104131399184
# 	round 18: 1.573346751902702
# 	round 19: 1.573436912352199
# 	round 20: 1.5727742527165587
# 	round 21: 1.5760614931458248
# 	round 22: 1.5713802739723053
# 	round 23: 1.5741849276509574
# 	round 24: 1.5723928663923958
# 	round 25: 1.5707435111572308
# 	round 26: 1.5717725491192374
# 	round 27: 1.567651174400058
# 	round 28: 1.5669317377673282
# 	round 29: 1.5640258584519813
# 	round 30: 1.568510140660834
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 50.83491650834917), (2, 77.71222877712229), (3, 82.56174382561744), (4, 88.41115888411159), (5, 90.51094890510949), (6, 90.95090490950905), (7, 91.63083691630837), (8, 92.34076592340766), (9, 92.4007599240076), (10, 92.92070792920708), (11, 93.46065393460654), (12, 93.36066393360665), (13, 93.37066293370663), (14, 93.49065093490651), (15, 93.75062493750625), (16, 94.14058594140586), (17, 93.67063293670633), (18, 94.15058494150585), (19, 94.34056594340566), (20, 94.25057494250575), (21, 94.22057794220578), (22, 94.5905409459054), (23, 94.28057194280572), (24, 94.47055294470553), (25, 94.41055894410559), (26, 94.26057394260575), (27, 94.68053194680532), (28, 94.77052294770523), (29, 95.07049295070493), (30, 94.5905409459054)]}

# %% [markdown]
# # 2번

# %%
# import flwr as fl
import os
import numpy as np

fraction_fit=1
fraction_eval=1
min_fit_clients=10
min_eval_clients=10
min_available_clients=10
num_rounds=30

def evaluate_metrics_aggregation_fn(eval_metrics):
    data_len = sum([num for num, met in eval_metrics])
    acc = sum([num*met['accuracy'] for num, met in eval_metrics])/data_len
    return {'accuracy' : acc}

strategy = fl.server.strategy.FedAvg(
    fraction_fit=fraction_fit,                    # 훈련을 위해서 사용 가능한 클라이언트의 100% 이용
    fraction_evaluate=fraction_eval,              # 평가를 위해서 사용 가능한 클라이언트의 100% 이용
    min_fit_clients=min_fit_clients,              # 훈련을 위해서는 적어도 5개 이상의 클라이언트가 필요
    min_evaluate_clients=min_eval_clients,        # 평가를 위해서는 적어도 5개 이상의 클라이언트가 필요
    min_available_clients=min_available_clients,  # 사용 가능한 클라이언트의 수가 5 될 때까지 대기
    evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
)

print('server start!')
output = fl.server.start_server(config=fl.server.ServerConfig(num_rounds=num_rounds), strategy=strategy)
output
# Out:
# INFO flwr 2023-08-23 17:16:53,760 | app.py:148 | Starting Flower server, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2023-08-23 17:16:53,768 | app.py:168 | Flower ECE: gRPC server running (30 rounds), SSL is disabled
# INFO flwr 2023-08-23 17:16:53,769 | server.py:86 | Initializing global parameters
# INFO flwr 2023-08-23 17:16:53,770 | server.py:273 | Requesting initial parameters from one random client
# server start!
# INFO flwr 2023-08-23 17:16:58,419 | server.py:277 | Received initial parameters from one random client
# INFO flwr 2023-08-23 17:16:58,420 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-08-23 17:16:58,421 | server.py:101 | FL starting
# DEBUG flwr 2023-08-23 17:17:14,176 | server.py:218 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:15,270 | server.py:232 | fit_round 1 received 10 results and 0 failures
# WARNING flwr 2023-08-23 17:17:15,278 | fedavg.py:243 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-08-23 17:17:15,278 | server.py:168 | evaluate_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:15,359 | server.py:182 | evaluate_round 1 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:15,360 | server.py:218 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:15,605 | server.py:232 | fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:15,615 | server.py:168 | evaluate_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:15,696 | server.py:182 | evaluate_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:15,697 | server.py:218 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:15,939 | server.py:232 | fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:15,948 | server.py:168 | evaluate_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:16,021 | server.py:182 | evaluate_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:16,022 | server.py:218 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:16,279 | server.py:232 | fit_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:16,289 | server.py:168 | evaluate_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:16,371 | server.py:182 | evaluate_round 4 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:16,372 | server.py:218 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:16,610 | server.py:232 | fit_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:16,620 | server.py:168 | evaluate_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:16,694 | server.py:182 | evaluate_round 5 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:16,695 | server.py:218 | fit_round 6: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:16,932 | server.py:232 | fit_round 6 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:16,938 | server.py:168 | evaluate_round 6: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:17,019 | server.py:182 | evaluate_round 6 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:17,020 | server.py:218 | fit_round 7: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:17,264 | server.py:232 | fit_round 7 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:17,275 | server.py:168 | evaluate_round 7: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:17,350 | server.py:182 | evaluate_round 7 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:17,351 | server.py:218 | fit_round 8: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:17,605 | server.py:232 | fit_round 8 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:17,616 | server.py:168 | evaluate_round 8: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:17,688 | server.py:182 | evaluate_round 8 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:17,689 | server.py:218 | fit_round 9: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:17,933 | server.py:232 | fit_round 9 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:17,943 | server.py:168 | evaluate_round 9: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,021 | server.py:182 | evaluate_round 9 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,022 | server.py:218 | fit_round 10: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,258 | server.py:232 | fit_round 10 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,268 | server.py:168 | evaluate_round 10: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,338 | server.py:182 | evaluate_round 10 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,339 | server.py:218 | fit_round 11: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,580 | server.py:232 | fit_round 11 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,591 | server.py:168 | evaluate_round 11: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,664 | server.py:182 | evaluate_round 11 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,665 | server.py:218 | fit_round 12: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,902 | server.py:232 | fit_round 12 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,913 | server.py:168 | evaluate_round 12: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:18,987 | server.py:182 | evaluate_round 12 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:18,988 | server.py:218 | fit_round 13: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:19,231 | server.py:232 | fit_round 13 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:19,238 | server.py:168 | evaluate_round 13: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:19,315 | server.py:182 | evaluate_round 13 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:19,316 | server.py:218 | fit_round 14: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:19,573 | server.py:232 | fit_round 14 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:19,583 | server.py:168 | evaluate_round 14: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:19,661 | server.py:182 | evaluate_round 14 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:19,662 | server.py:218 | fit_round 15: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:19,898 | server.py:232 | fit_round 15 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:19,904 | server.py:168 | evaluate_round 15: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:19,977 | server.py:182 | evaluate_round 15 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:19,978 | server.py:218 | fit_round 16: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:20,248 | server.py:232 | fit_round 16 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:20,258 | server.py:168 | evaluate_round 16: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:20,339 | server.py:182 | evaluate_round 16 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:20,340 | server.py:218 | fit_round 17: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:20,608 | server.py:232 | fit_round 17 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:20,615 | server.py:168 | evaluate_round 17: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:20,694 | server.py:182 | evaluate_round 17 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:20,695 | server.py:218 | fit_round 18: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:20,927 | server.py:232 | fit_round 18 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:20,935 | server.py:168 | evaluate_round 18: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:21,007 | server.py:182 | evaluate_round 18 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:21,007 | server.py:218 | fit_round 19: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:21,288 | server.py:232 | fit_round 19 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:21,299 | server.py:168 | evaluate_round 19: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:21,376 | server.py:182 | evaluate_round 19 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:21,377 | server.py:218 | fit_round 20: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:21,631 | server.py:232 | fit_round 20 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:21,641 | server.py:168 | evaluate_round 20: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:21,719 | server.py:182 | evaluate_round 20 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:21,720 | server.py:218 | fit_round 21: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:21,973 | server.py:232 | fit_round 21 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:21,984 | server.py:168 | evaluate_round 21: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:22,065 | server.py:182 | evaluate_round 21 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:22,066 | server.py:218 | fit_round 22: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:22,300 | server.py:232 | fit_round 22 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:22,306 | server.py:168 | evaluate_round 22: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:22,381 | server.py:182 | evaluate_round 22 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:22,382 | server.py:218 | fit_round 23: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:22,622 | server.py:232 | fit_round 23 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:22,633 | server.py:168 | evaluate_round 23: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:22,710 | server.py:182 | evaluate_round 23 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:22,711 | server.py:218 | fit_round 24: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:22,971 | server.py:232 | fit_round 24 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:22,981 | server.py:168 | evaluate_round 24: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:23,060 | server.py:182 | evaluate_round 24 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:23,061 | server.py:218 | fit_round 25: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:23,306 | server.py:232 | fit_round 25 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:23,316 | server.py:168 | evaluate_round 25: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:23,394 | server.py:182 | evaluate_round 25 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:23,395 | server.py:218 | fit_round 26: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:23,639 | server.py:232 | fit_round 26 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:23,649 | server.py:168 | evaluate_round 26: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:23,725 | server.py:182 | evaluate_round 26 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:23,726 | server.py:218 | fit_round 27: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:23,991 | server.py:232 | fit_round 27 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,001 | server.py:168 | evaluate_round 27: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:24,080 | server.py:182 | evaluate_round 27 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,080 | server.py:218 | fit_round 28: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:24,313 | server.py:232 | fit_round 28 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,322 | server.py:168 | evaluate_round 28: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:24,397 | server.py:182 | evaluate_round 28 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,397 | server.py:218 | fit_round 29: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:24,641 | server.py:232 | fit_round 29 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,647 | server.py:168 | evaluate_round 29: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:24,723 | server.py:182 | evaluate_round 29 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,723 | server.py:218 | fit_round 30: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:24,954 | server.py:232 | fit_round 30 received 10 results and 0 failures
# DEBUG flwr 2023-08-23 17:17:24,963 | server.py:168 | evaluate_round 30: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-08-23 17:17:25,037 | server.py:182 | evaluate_round 30 received 10 results and 0 failures
# INFO flwr 2023-08-23 17:17:25,038 | server.py:147 | FL finished in 26.616460502991686
# INFO flwr 2023-08-23 17:17:25,039 | app.py:218 | app_fit: losses_distributed [(1, 2.4242594262599946), (2, 2.395824565219879), (3, 2.4010292894124983), (4, 2.3594640897750856), (5, 2.2603237553358078), (6, 2.301958594882488), (7, 2.3238719512581825), (8, 2.2072162328600884), (9, 2.2827252215623854), (10, 2.368622589838505), (11, 2.3374274108171464), (12, 2.2690142734646797), (13, 2.229564789402485), (14, 2.239749442720413), (15, 2.2340381165981293), (16, 2.2680914039850233), (17, 2.219611876010895), (18, 2.138171119904518), (19, 2.080844474387169), (20, 2.105629335796833), (21, 2.025182285249233), (22, 2.160693001759052), (23, 2.089769266486168), (24, 2.1514728705763817), (25, 2.190617019701004), (26, 2.1181636838912965), (27, 2.2755998433351516), (28, 2.138863692009449), (29, 2.0887602323532106), (30, 2.2177908113479616)]
# INFO flwr 2023-08-23 17:17:25,039 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-08-23 17:17:25,040 | app.py:220 | app_fit: metrics_distributed {'accuracy': [(1, 13.64), (2, 18.05), (3, 16.56), (4, 20.54), (5, 30.44), (6, 26.21), (7, 24.52), (8, 35.6), (9, 28.28), (10, 20.87), (11, 22.37), (12, 30.05), (13, 32.95), (14, 32.71), (15, 31.63), (16, 30.41), (17, 33.23), (18, 43.07), (19, 48.16), (20, 45.92), (21, 52.67), (22, 39.84), (23, 47.34), (24, 40.89), (25, 36.12), (26, 44.46), (27, 28.91), (28, 41.64), (29, 46.65), (30, 33.86)]}
# INFO flwr 2023-08-23 17:17:25,040 | app.py:221 | app_fit: losses_centralized []
# INFO flwr 2023-08-23 17:17:25,041 | app.py:222 | app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 2.4242594262599946
# 	round 2: 2.395824565219879
# 	round 3: 2.4010292894124983
# 	round 4: 2.3594640897750856
# 	round 5: 2.2603237553358078
# 	round 6: 2.301958594882488
# 	round 7: 2.3238719512581825
# 	round 8: 2.2072162328600884
# 	round 9: 2.2827252215623854
# 	round 10: 2.368622589838505
# 	round 11: 2.3374274108171464
# 	round 12: 2.2690142734646797
# 	round 13: 2.229564789402485
# 	round 14: 2.239749442720413
# 	round 15: 2.2340381165981293
# 	round 16: 2.2680914039850233
# 	round 17: 2.219611876010895
# 	round 18: 2.138171119904518
# 	round 19: 2.080844474387169
# 	round 20: 2.105629335796833
# 	round 21: 2.025182285249233
# 	round 22: 2.160693001759052
# 	round 23: 2.089769266486168
# 	round 24: 2.1514728705763817
# 	round 25: 2.190617019701004
# 	round 26: 2.1181636838912965
# 	round 27: 2.2755998433351516
# 	round 28: 2.138863692009449
# 	round 29: 2.0887602323532106
# 	round 30: 2.2177908113479616
# History (metrics, distributed, evaluate):
# {'accuracy': [(1, 13.64), (2, 18.05), (3, 16.56), (4, 20.54), (5, 30.44), (6, 26.21), (7, 24.52), (8, 35.6), (9, 28.28), (10, 20.87), (11, 22.37), (12, 30.05), (13, 32.95), (14, 32.71), (15, 31.63), (16, 30.41), (17, 33.23), (18, 43.07), (19, 48.16), (20, 45.92), (21, 52.67), (22, 39.84), (23, 47.34), (24, 40.89), (25, 36.12), (26, 44.46), (27, 28.91), (28, 41.64), (29, 46.65), (30, 33.86)]}
